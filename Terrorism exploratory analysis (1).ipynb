# %% [markdown]
# # Exploratory Data Analysis on Dataset- Terrorism

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib

# %% [markdown]
# ### Reading dataset

# %%
df = pd.read_csv("C:\\Users\\hp\\Downloads\\globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### Understanding data

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.size
# Out:
# 24528285

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Correlation

# %%
df.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %% [markdown]
# ### Exploratory Analysis

# %%
df['country_txt'].value_counts()
# Out:
# Iraq                24636
# Pakistan            14368
# Afghanistan         12731
# India               11960
# Colombia             8306
#                     ...
# Andorra                 1
# Vatican City            1
# Falkland Islands        1
# South Vietnam           1
# North Korea             1
# Name: country_txt, Length: 205, dtype: int64

# %%
plt.figure(figsize=(20,7))
c = df['country_txt'].value_counts().index
sns.countplot(df['country_txt'], order=c[:16]);
plt.xlabel('Countries')
plt.ylabel('Death rate')
plt.title('Top 15 Countries under threat')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Types of Attack
df['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
plt.figure(figsize=(20,7))
attack = df['attacktype1_txt'].value_counts().index
sns.countplot(df['attacktype1_txt'], order=attack[:]);
plt.xlabel('Attack type')
plt.ylabel('Attack count')
plt.title('Types of attacks')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Attacks each year
plt.subplots(figsize=(15,6))
sns.countplot('iyear', data=df)
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.title('Terrorism Activities per year')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#attacks regionwise
df['region_txt'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: region_txt, dtype: int64

# %%
group_attack = df['gname'].value_counts()
group_attack
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# King Street                                             1
# Martyr al-Nimr Battalion                                1
# Sons of the Gestapo                                     1
# Portuguese Liberation Army                              1
# Demonstration led by French Anti-Nazi Hunters           1
# Name: gname, Length: 3537, dtype: int64

# %%
ES_attacks = df[df.country_txt=='El Salvador'].reset_index()

# %%
ES_attacks.head()
# Out:
#    index       eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0   1615  197211050001   1972      11     5        NaN         0        NaN
# 1   1624  197211150001   1972      11    15        NaN         0        NaN
# 2   1856  197304290001   1973       4    29        NaN         0        NaN
# 3   2211  197402000001   1974       2     0        NaN         0        NaN
# 4   2265  197403060001   1974       3     6        NaN         0        NaN
#
#    country  country_txt  ...  addnotes scite1 scite2 scite3  dbsource  \
# 0       61  El Salvador  ...       NaN    NaN    NaN    NaN      PGIS
# 1       61  El Salvador  ...       NaN    NaN    NaN    NaN      PGIS
# 2       61  El Salvador  ...       NaN    NaN    NaN    NaN      PGIS
# 3       61  El Salvador  ...       NaN    NaN    NaN    NaN      PGIS
# 4       61  El Salvador  ...       NaN    NaN    NaN    NaN      PGIS
#
#    INT_LOG  INT_IDEO  INT_MISC INT_ANY related
# ...

# %%
print(f"""{ES_attacks.city.nunique()} cities were attacked by {ES_attacks.gname.nunique()} terrorist groups between the year {ES_attacks.iyear.min()} and {ES_attacks.iyear.max()}.
 The total number of terrorist attacks in El Salvador is {ES_attacks.index.nunique()}""")
# Out:
# 596 cities were attacked by 49 terrorist groups between the year 1972 and 1997.
#  The total number of terrorist attacks in El Salvador is 5320
